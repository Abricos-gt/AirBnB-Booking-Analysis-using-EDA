# %% [markdown]
# # 🏠 AirBnB Booking Analysis Using Exploratory Data Analysis (EDA)

# %% [markdown]
# 📌 Introduction
#
# Exploratory Data Analysis (EDA) is a fundamental step in understanding the structure, quality, and patterns within a dataset before drawing conclusions or building predictive models.
#
# In this project, we perform a comprehensive EDA on an AirBnB listings dataset to uncover meaningful insights about pricing behavior, geographic distribution, host characteristics, and market dynamics.
#
# The focus of this analysis is not predictive modeling, but rather:
#
# - Understanding the dataset deeply
#
# - Cleaning and validating the data
#
# - Visualizing patterns effectively
#
# - Extracting actionable business insights
#
# Through systematic exploration and visualization, this project aims to transform raw listing data into meaningful knowledge.

# %% [markdown]
# 🌍 About the AirBnB Platform
#
# AirBnB is a global online marketplace that connects property owners (hosts) with travelers seeking short-term accommodations. Founded in 2008, the platform has expanded rapidly and now operates in over 220 countries and regions worldwide.
#
# AirBnB offers diverse lodging options, including:
#
# - Private rooms
#
# - Entire apartments or houses
#
# - Shared spaces
#
# - Unique stays (e.g., treehouses, villas, castles)
#
# This diversity allows travelers to choose accommodations that match their preferences and budget, while hosts can generate income from unused or underutilized spaces.

# %% [markdown]
# 🎯 Objective of This Analysis
#
# The primary objective of this project is to analyze AirBnB listing data using EDA techniques to understand:
#
# - How listings are distributed across neighborhoods
#
# - What factors influence pricing
#
# - The role of host verification
#
# - Geographic concentration of listings
#
# - Market patterns within the selected city
#
# This analysis aims to develop strong visualization and interpretation skills by answering key business-driven questions using data.

# %% [markdown]
# This project follows a structured EDA process:
#
# - Data Understanding – Reviewing structure, types, and missing values
#
# - Data Cleaning – Fixing inconsistencies and ensuring reliability
#
# - Univariate Analysis – Studying individual feature distributions
#
# - Bivariate Analysis – Exploring relationships between variables
#
# - Insight Extraction – Translating patterns into business meaning
#
# Each visualization will be accompanied by interpretation to ensure insights go beyond descriptive statistics.

# %%
# importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
